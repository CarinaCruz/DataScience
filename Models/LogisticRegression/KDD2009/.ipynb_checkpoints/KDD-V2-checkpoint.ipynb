# %% [markdown]
# # <b> Análise de Dados - Gestão de Relacionamento com o Cliente

# %% [markdown]
# ### <b> Knowledge Discovery and Data Mining (KDD)

# %% [markdown]
# ## <b> Import das bibliotecas

# %%
##############
# Bibliotecas 
##############
import numpy as np
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as plt

##################
# Machine Learning
##################
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import Imputer
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
# Importando o Classificadores
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression 
# Importando métricas de avaliação do SKLearn
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn import svm


# comando que imprime todas as linhas 
pd.set_option('display.max_rows', None)
# comando que imprime todas as colunas
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## <b> Carregando os dados

# %%
# Carregando os dados
data_train = pd.read_csv('orange_small_train.data',  sep = '\t')
data_test = pd.read_csv('orange_small_test.data',  sep = '\t')
up_label = pd.read_csv('train_upselling.labels',  sep = '\t')
churn_label = pd.read_csv('train_churn.labels',  sep = '\t')
appetency_label = pd.read_csv('train_appetency.labels',  sep = '\t')

# %% [markdown]
# ## <b> Visualizando informações sobre os dados

# %%
# Visualizando os dados de treino em seu estado natural
data_train.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10  Var11  \
# 0   NaN   NaN   NaN   NaN   NaN  1526.0   7.0   NaN   NaN    NaN    NaN
# 1   NaN   NaN   NaN   NaN   NaN   525.0   0.0   NaN   NaN    NaN    NaN
# 2   NaN   NaN   NaN   NaN   NaN  5236.0   7.0   NaN   NaN    NaN    NaN
# 3   NaN   NaN   NaN   NaN   NaN     NaN   0.0   NaN   NaN    NaN    NaN
# 4   NaN   NaN   NaN   NaN   NaN  1029.0   7.0   NaN   NaN    NaN    NaN
#
#    Var12   Var13  Var14  Var15  Var16  Var17  Var18  Var19  Var20   Var21  \
# 0    NaN   184.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN   464.0
# 1    NaN     0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN   168.0
# 2    NaN   904.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  1212.0
# 3    NaN     0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 4    NaN  3216.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    64.0
#
#     Var22  Var23  Var24  Var25  Var26  Var27   Var28  Var29  Var30  Var31  \
# 0   580.0    NaN   14.0  128.0    NaN    NaN  166.56    NaN    NaN    NaN
# 1   210.0    NaN    2.0   24.0    NaN    NaN  353.52    NaN    NaN    NaN
# 2  1515.0    NaN   26.0  816.0    NaN    NaN  220.08    NaN    NaN    NaN
# 3     0.0    NaN    NaN    0.0    NaN    NaN   22.08    NaN    NaN    NaN
# 4    80.0    NaN    4.0   64.0    NaN    NaN  200.00    NaN    NaN    NaN
#
#    Var32  Var33  Var34  Var35  Var36  Var37      Var38  Var39  Var40  Var41  \
# 0    NaN    NaN    NaN    0.0    NaN    NaN     3570.0    NaN    NaN    NaN
# 1    NaN    NaN    NaN    0.0    NaN    NaN  4764966.0    NaN    NaN    NaN
# 2    NaN    NaN    NaN    0.0    NaN    NaN  5883894.0    NaN    NaN    NaN
# 3    NaN    NaN    NaN    0.0    NaN    NaN        0.0    NaN    NaN    NaN
# 4    NaN    NaN    NaN    0.0    NaN    NaN        0.0    NaN    NaN    NaN
#
#    Var42  Var43  Var44  Var45  Var46  Var47  Var48  Var49  Var50  Var51  \
# 0    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    Var52  Var53  Var54  Var55  Var56     Var57  Var58  Var59  Var60  Var61  \
# 0    NaN    NaN    NaN    NaN    NaN  4.076907    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN  5.408032    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN  6.599658    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN  1.988250    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN  4.552446    NaN    NaN    NaN    NaN
#
#    Var62  Var63  Var64  Var65  Var66  Var67  Var68  Var69  Var70  Var71  \
# 0    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN   18.0    NaN    NaN    NaN    NaN    NaN    NaN
#
#    Var72  Var73  Var74  Var75      Var76  Var77  Var78  Var79  Var80  \
# 0    NaN     36   35.0    NaN  1350864.0    NaN    0.0    NaN    NaN
# 1    3.0     26    0.0    NaN  2872928.0    NaN    3.0    NaN    NaN
# 2    NaN    130  518.0    NaN  1675776.0    NaN    0.0    NaN    NaN
# 3    NaN     12    0.0    NaN        0.0    NaN    0.0    NaN    NaN
# 4    3.0     82  224.0    NaN   784448.0    NaN    0.0    NaN    NaN
#
#        Var81  Var82  Var83  Var84  Var85  Var86  Var87  Var88  Var89  Var90  \
# 0    7333.11    NaN    5.0    NaN   12.0    NaN    NaN    NaN    NaN    NaN
# 1  151098.90    NaN   25.0    NaN    2.0    NaN    NaN    NaN    NaN    Na
NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Var189  Var190 Var191      Var192   Var193 Var194 Var195 Var196 Var197  \
# 0   462.0     NaN    NaN  bZkvyxLkBI     RO12    NaN   taul   1K8T   lK27
# 1     NaN     NaN    NaN  CEat0G8rTN     RO12    NaN   taul   1K8T   2Ix5
# 2     NaN     NaN    NaN  eOQt0GoOh3  AERks4l   SEuy   taul   1K8T   ffXs
# 3     NaN     NaN    NaN  jg69tYsGvO     RO12    NaN   taul   1K8T   ssAy
# 4     NaN     NaN    NaN  IXSgUHShse     RO12   SEuy   taul   1K8T   uNkU
#
#     Var198         Var199   Var200 Var201 Var202 Var203 Var204   Var205  \
# 0  ka_ns41     nQUveAzAF7      NaN    NaN   dXGu   9_Y1   FbIm     VpdQ
# 1  qEdASpP     y2LIM01bE1      NaN    NaN   lg1t   9_Y1   k13i  sJzTlal
# 2  NldASpP        y4g9XoZ  vynJTq9   smXZ   4bTR   9_Y1   MGOA     VpdQ
# 3  _ybO0dd  4hMlgkf58mhwh      NaN    NaN   W8mQ   9_Y1   YULl     VpdQ
# 4  EKR938I        ThrHXVS  0v21jmy   smXZ   xklU   9_Y1   RVjC  sJzTlal
#
#   Var206                     Var207 Var208  Var209 Var210 Var211  \
# 0   haYg                 me75fM6ugJ   kIsH     NaN   uKAI   L84s
# 1   zm5i                 me75fM6ugJ   kIsH     NaN   uKAI   L84s
# 2   haYg  DHn_WUyBhW_whjA88g9bvA64_   kIsH     NaN   uKAI   L84s
# 3    NaN                 me75fM6ugJ   kIsH     NaN   uKAI   Mtgm
# 4   6JmL                 me75fM6ugJ   kIsH     NaN   uKAI   L84s
#
#           Var212 Var213   Var214 Var215   Var216 Var217 Var218 Var219  \
# 0  XfqtO3UdzaXh_    NaN      NaN    NaN  XTbPUYD   sH5Z   cJvF   FzaX
# 1        NhsEn4L    NaN      NaN    NaN  kZJyVg2    NaN    NaN   FzaX
# 2        UbxQ8lZ    NaN  TTGHfSv    NaN  pMWAe2U   bHR7   UYBR   FzaX
# 3        NhsEn4L    NaN      NaN    NaN  kq0dQfu   eKej   UYBR   FzaX
# 4  XfqtO3UdzaXh_    NaN  SJs3duv    NaN  11p4mKe   H3p7   UYBR   FzaX
#
#     Var220   Var221   Var222      Var223 Var224 Var225 Var226   Var227  \
# 0  1YVfGrO     oslk  fXVEsaq  jySVZNlOJy    NaN    NaN   xb3V     RAYp
# 1  0AJo2f2     oslk  2Kb5FSF  LM8l689qOp    NaN    NaN   fKCe     RAYp
# 2  JFM1BiF  Al6ZaUT  NKv4yOc  jySVZNlOJy    NaN   kG3k   Qu4f  02N6s8f
# 3  L91KIiz     oslk  CE7uk3u  LM8l689qOp    NaN    NaN   FSa2     RAYp
# 4  OrnLfvc     oslk  1J2cvxe  LM8l689qOp    NaN   kG3k   FSa2     RAYp
#
#           Var228 Var229  Var230
# 0  F2FyR07IdsN7I    NaN     NaN
# 1  F2FyR07IdsN7I    NaN     NaN
# 2  ib5G6X1eUxUn6   am7c     NaN
# 3  F2FyR07IdsN7I    NaN     NaN
# 4  F2FyR07IdsN7I   mj86     NaN

# %%
# Visualizando os dados de teste me seu estado natural
data_test.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10  Var11  \
# 0   NaN   NaN   NaN   NaN   NaN  1225.0   7.0   NaN   NaN    NaN    NaN
# 1   NaN   NaN   NaN   NaN   NaN
# 3   SEuy   taul   1K8T   tzKK  Te2s8CN        hOpRIhsUSP  x0xpMjN   smXZ
# 4    NaN   taul   1K8T   80HR  fqeOwLG     nJy8d8N5V7yiy  IBmPo7a    NaN
#
#   Var202 Var203 Var204 Var205 Var206               Var207 Var208  Var209  \
# 0   WVvO   9_Y1   vm5R   VpdQ   haYg  7M47J5GA0pTYIFxg5uy   kIsH     NaN
# 1   aFB2   9_Y1   t_4G   VpdQ   zm5i           me75fM6ugJ   kIsH     NaN
# 2   6k5I   9_Y1   iVbl   VpdQ   zm5i           me75fM6ugJ   kIsH     NaN
# 3   kVZt   9_Y1   vm5R   VpdQ   6JmL           me75fM6ugJ   kIsH     NaN
# 4   oyu5   9_Y1   WIr3   VpdQ   kxE9  7M47J5GA0pTYIFxg5uy   kIsH     NaN
#
#   Var210 Var211         Var212 Var213   Var214 Var215   Var216 Var217 Var218  \
# 0   uKAI   L84s  H4p93_uThXwSG    NaN  XREFJCi    NaN  7WwzJJY   OgPm   cJvF
# 1   uKAI   L84s        NhsEn4L    NaN      NaN    NaN  kZJyVg2   4ls8   cJvF
# 2   uKAI   L84s        NhsEn4L    NaN      NaN    NaN  kZJtVhC   0b0w   cJvF
# 3   uKAI   L84s  XfqtO3UdzaXh_    NaN  3yoa8Yv    NaN  XTbPUYD   XqfQ   UYBR
# 4   uKAI   L84s  H4p93_uThXwSG    NaN  c02HCHI    NaN  _JdEa95   bOvW   cJvF
#
#     Var219   Var220   Var221   Var222      Var223 Var224 Var225 Var226 Var227  \
# 0     FzaX  ch2oGfM  Al6ZaUT  P6pu4Vl  LM8l689qOp    NaN   ELof   7P5s   ZI9m
# 1     FzaX  Kgofc8E     oslk  S46Rt72  LM8l689qOp    NaN    NaN   Qu4f   RAYp
# 2     FzaX  bBmOw16     oslk  CcdTy9x  LM8l689qOp    NaN    NaN   7aLG   RAYp
# 3  AU8pNoi  rDm6pd1     oslk  Q53Rkup  LM8l689qOp    NaN   kG3k   7P5s   RAYp
# 4     FzaX  fxJmel6  Al6ZaUT  WfsWw2A  LM8l689qOp    NaN   ELof   5Acm   ZI9m
#
#                 Var228 Var229  Var230
# 0     R4y5gQQWY8OodqDV    NaN     NaN
# 1        F2FyR07IdsN7I    NaN     NaN
# 2        F2FyR07IdsN7I    NaN     NaN
# 3  TCU50_Yjmm6GIBZ0lL_   am7c     NaN
# 4           iyHGyLCEkQ   am7c     NaN

# %%
# visualizando a quantidade de linhas e colunas
print("Teste = ", data_test.shape)
print("Treino = ", data_train.shape)
print("Variáveis Target = ", up_label.shape, churn_label.shape, appetency_label.shape)
# Out:
# Teste =  (50000, 230)
# Treino =  (50000, 230)
# Variáveis Target =  (49999, 1) (49999, 1) (49999, 1)

# %%
# Informações sobre o data set test
print(data_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 230 entries, Var1 to Var230
# dtypes: float64(191), int64(1), object(38)
# memory usage: 87.7+ MB
# None

# %%
# Informações sobre o data set train
print(data_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 230 entries, Var1 to Var230
# dtypes: float64(191), int64(1), object(38)
# memory usage: 87.7+ MB
# None

# %% [markdown]
# ## <b> Tratamento os dados das colunas

# %% [markdown]
# ### <b> Separação do dataset Train (em numérico e object)

# %%
# Seleciona os nomes das colunas (train)
colunas = list(data_train.columns)

# Separa o conjunto de dados train em dois novos conjuntos um de numéricos e outro object
obj_train = [x for x in colunas if data_train[x].dtype == 'O'] 
num_train = [x for x in colunas if data_train[x].dtype != 'O']

# %%
# Exclui as numéricas e cria um novo dataset com valores object
data_obj_train = data_train.drop(num_train, axis=1)

# %%
# Visualizando as primeiras linhas do dataset de valores object
data_obj_train.head()
# Out:
#   Var191      Var192   Var193 Var194 Var195 Var196 Var197   Var198  \
# 0    NaN  bZkvyxLkBI     RO12    NaN   taul   1K8T   lK27  ka_ns41
# 1    NaN  CEat0G8rTN     RO12    NaN   taul   1K8T   2Ix5  qEdASpP
# 2    NaN  eOQt0GoOh3  AERks4l   SEuy   taul   1K8T   ffXs  NldASpP
# 3    NaN  jg69tYsGvO     RO12    NaN   taul   1K8T   ssAy  _ybO0dd
# 4    NaN  IXSgUHShse     RO12   SEuy   taul   1K8T   uNkU  EKR938I
#
#           Var199   Var200 Var201 Var202 Var203 Var204   Var205 Var206  \
# 0     nQUveAzAF7      NaN    NaN   dXGu   9_Y1   FbIm     VpdQ   haYg
# 1     y2LIM01bE1      NaN    NaN   lg1t   9_Y1   k13i  sJzTlal   zm5i
# 2        y4g9XoZ  vynJTq9   smXZ   4bTR   9_Y1   MGOA     VpdQ   haYg
# 3  4hMlgkf58mhwh      NaN    NaN   W8mQ   9_Y1   YULl     VpdQ    NaN
# 4        ThrHXVS  0v21jmy   smXZ   xklU   9_Y1   RVjC  sJzTlal   6JmL
#
#                       Var207 Var208 Var210 Var211         Var212 Var213  \
# 0                 me75fM6ugJ   kIsH   uKAI   L84s  XfqtO3UdzaXh_    NaN
# 1                 me75fM6ugJ   kIsH   uKAI   L84s        NhsEn4L    NaN
# 2  DHn_WUyBhW_whjA88g9bvA64_   kIsH   uKAI   L84s        UbxQ8lZ    NaN
# 3                 me75fM6ugJ   kIsH   uKAI   Mtgm        NhsEn4L    NaN
# 4                 me75fM6ugJ   kIsH   uKAI   L84s  XfqtO3UdzaXh_    NaN
#
#     Var214 Var215   Var216 Var217 Var218 Var219   Var220   Var221   Var222  \
# 0      NaN    NaN  XTbPUYD   sH5Z   cJvF   FzaX  1YVfGrO     oslk  fXVEsaq
# 1      NaN    NaN  kZJyVg2    NaN    NaN   FzaX  0AJo2f2     oslk  2Kb5FSF
# 2  TTGHfSv    NaN  pMWAe2U   bHR7   UYBR   FzaX  JFM1BiF  Al6ZaUT  NKv4yOc
# 3      NaN    NaN  kq0dQfu   eKej   UYBR   FzaX  L91KIiz     oslk  CE7uk3u
# 4  SJs3duv    NaN  11p4mKe   H3p7   UYBR   FzaX  OrnLfvc     oslk  1J2cvxe
#
#        Var223 Var224 Var225 Var226   Var227         Var228 Var229
# 0  jySVZNlOJy    NaN    NaN   xb3V     RAYp  F2FyR07IdsN7I    NaN
# 1  LM8l689qOp    NaN    NaN   fKCe     RAYp  F2FyR07IdsN7I    NaN
# 2  jySVZNlOJy    NaN   kG3k   Qu4f  02N6s8f  ib5G6X1eUxUn6   am7c
# 3  LM8l689qOp    NaN    NaN   FSa2     RAYp  F2FyR07IdsN7I    NaN
# 4  LM8l689qOp    NaN   kG3k   FSa2     RAYp  F2FyR07IdsN7I   mj86

# %%
# Exclui as categóricas e cria um novo dataset com as numéricas
data_num_train = data_train.drop(obj_train, axis=1)

# %%
# Visualizando as primeiras linhas do dataset de valores numéricos
data_num_train.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10  Var11  \
# 0   NaN   NaN   NaN   NaN   NaN  1526.0   7.0   NaN   NaN    NaN    NaN
# 1   NaN   NaN   NaN   NaN   NaN   525.0   0.0   NaN   NaN    NaN    NaN
# 2   NaN   NaN   NaN   NaN   NaN  5236.0   7.0   NaN   NaN    NaN    NaN
# 3   NaN   NaN   NaN   NaN   NaN     NaN   0.0   NaN   NaN    NaN    NaN
# 4   NaN   NaN   NaN   NaN   NaN  1029.0   7.0   NaN   NaN    NaN    NaN
#
#    Var12   Var13  Var14  Var15  Var16  Var17  Var18  Var19  Var20   Var21  \
# 0    NaN   184.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN   464.0
# 1    NaN     0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN   168.0
# 2    NaN   904.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  1212.0
# 3    NaN     0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 4    NaN  3216.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    64.0
#
#     Var22  Var23  Var24  Var25  Var26  Var27   Var28  Var29  Var30  Var31  \
# 0   580.0    NaN   14.0  128.0    NaN    NaN  166.56    NaN    NaN    NaN
# 1   210.0    NaN    2.0   24.0    NaN    NaN  353.52    NaN    NaN    NaN
# 2  1515.0    NaN   26.0  816.0    NaN    NaN  220.08    NaN    NaN    NaN
# 3     0.0    NaN    NaN    0.0    NaN    NaN   22.08    NaN    NaN    NaN
# 4    80.0    NaN    4.0   64.0    NaN    NaN  200.00    NaN    NaN    NaN
#
#    Var32  Var33  Var34  Var35  Var36  Var37      Var38  Var39  Var40  Var41  \
# 0    NaN    NaN    NaN    0.0    NaN    NaN     3570.0    NaN    NaN    NaN
# 1    NaN    NaN    NaN    0.0    NaN    NaN  4764966.0    NaN    NaN    NaN
# 2    NaN    NaN    NaN    0.0    NaN    NaN  5883894.0    NaN    NaN    NaN
# 3    NaN    NaN    NaN    0.0    NaN    NaN        0.0    NaN    NaN    NaN
# 4    NaN    NaN    NaN    0.0    NaN    NaN        0.0    NaN    NaN    NaN
#
#    Var42  Var43  Var44  Var45  Var46  Var47  Var48  Var49  Var50  Var51  \
# 0    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    Var52  Var53  Var54  Var55  Var56     Var57  Var58  Var59  Var60  Var61  \
# 0    NaN    NaN    NaN    NaN    NaN  4.076907    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN  5.408032    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN  6.599658    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN  1.988250    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN  4.552446    NaN    NaN    NaN    NaN
#
#    Var62  Var63  Var64  Var65  Var66  Var67  Var68  Var69  Var70  Var71  \
# 0    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN   18.0    NaN    NaN    NaN    NaN    NaN    NaN
#
#    Var72  Var73  Var74  Var75      Var76  Var77  Var78  Var79  Var80  \
# 0    NaN     36   35.0    NaN  1350864.0    NaN    0.0    NaN    NaN
# 1    3.0     26    0.0    NaN  2872928.0    NaN    3.0    NaN    NaN
# 2    NaN    130  518.0    NaN  1675776.0    NaN    0.0    NaN    NaN
# 3    NaN     12    0.0    NaN        0.0    NaN    0.0    NaN    NaN
# 4    3.0     82  224.0    NaN   784448.0    NaN    0.0    NaN    NaN
#
#        Var81  Var82  Var83  Var84  Var85  Var86  Var87  Var88  Var89  Var90  \
# 0    7333.11    NaN    5.0    NaN   12.0    NaN    NaN    NaN    NaN    NaN
# 1  151098.90    NaN   25.0    NaN    2.0    NaN    NaN    NaN    NaN    NaN
# 2   16211.58    NaN   40.0    NaN   58.0    NaN    NaN    NaN    NaN    NaN
# 3        NaN    NaN    0.0    NaN    0.0    NaN    NaN    NaN    NaN    NaN
# 4   37423.50    NaN    0.0    NaN    0.0    NaN    NaN    NaN    NaN    NaN
0     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN

# %%
# Visualizando a quantidade de linhas e colunas
print("Shape do conjunto de dados de treino numérico (train)", data_num_train.shape)
print("Shape do conjunto de dados de treino object (train)", data_obj_train.shape)
# Out:
# Shape do conjunto de dados de treino numérico (train) (50000, 192)
# Shape do conjunto de dados de treino object (train) (50000, 38)

# %% [markdown]
# ### <b>Separação do dataset Test (em numérico e object)

# %%
# Seleciona os nomes das colunas (train)
colunas = list(data_test.columns)

# Separa o conjunto de dados test em dois novos conjuntos um de numéricos e outro object
obj_test = [x for x in colunas if data_test[x].dtype == 'O'] 
num_test = [x for x in colunas if data_test[x].dtype != 'O']

# %%
# Exclui as numéricas e cria um novo dataset com as variáveis object
data_obj_test = data_test.drop(num_test, axis=1)

# %%
# Visualização das primeiras linhas da coluna object de test
data_obj_test[0:5]
# Out:
#   Var191      Var192                              Var193 Var194 Var195 Var196  \
# 0    NaN  xddq9ayfAo                                RO12    NaN   taul   1K8T
# 1    NaN  cFHt0GoOh3                                RO12    NaN   taul   1K8T
# 2    NaN  zcROj17IEC                                RO12    NaN   taul   1K8T
# 3    NaN  gOyq9ayE15                             2Knk1KF   SEuy   taul   1K8T
# 4    NaN  voArjIXt5a  onTuEhrJJQy_H3IHkZku5AFczhYGqxJ890    NaN   taul   1K8T
#
#   Var197   Var198            Var199   Var200 Var201 Var202 Var203 Var204  \
# 0   PShj  iJzviRg  17VONbZnAuZ90atz  MF5EBmj    NaN   WVvO   9_Y1   vm5R
# 1   lK27  rsmctTK        7ONkRNQCK7      NaN    NaN   aFB2   9_Y1   t_4G
# 2   oXaB  I6Bd3iM           bGUqwlz      NaN    NaN   6k5I   9_Y1   iVbl
# 3   tzKK  Te2s8CN        hOpRIhsUSP  x0xpMjN   smXZ   kVZt   9_Y1   vm5R
# 4   80HR  fqeOwLG     nJy8d8N5V7yiy  IBmPo7a    NaN   oyu5   9_Y1   WIr3
#
#   Var205 Var206               Var207 Var208 Var210 Var211         Var212  \
# 0   VpdQ   haYg  7M47J5GA0pTYIFxg5uy   kIsH   uKAI   L84s  H4p93_uThXwSG
# 1   VpdQ   zm5i           me75fM6ugJ   kIsH   uKAI   L84s        NhsEn4L
# 2   VpdQ   zm5i           me75fM6ugJ   kIsH   uKAI   L84s        NhsEn4L
# 3   VpdQ   6JmL           me75fM6ugJ   kIsH   uKAI   L84s  XfqtO3UdzaXh_
# 4   VpdQ   kxE9  7M47J5GA0pTYIFxg5uy   kIsH   uKAI   L84s  H4p93_uThXwSG
#
#   Var213   Var214 Var215   Var216 Var217 Var218   Var219   Var220   Var221  \
# 0    NaN  XREFJCi    NaN  7WwzJJY   OgPm   cJvF     FzaX  ch2oGfM  Al6ZaUT
# 1    NaN      NaN    NaN  kZJyVg2   4ls8   cJvF     FzaX  Kgofc8E     oslk
# 2    NaN      NaN    NaN  kZJtVhC   0b0w   cJvF     FzaX  bBmOw16     oslk
# 3    NaN  3yoa8Yv    NaN  XTbPUYD   XqfQ   UYBR  AU8pNoi  rDm6pd1     oslk
# 4    NaN  c02HCHI    NaN  _JdEa95   bOvW   cJvF     FzaX  fxJmel6  Al6ZaUT
#
#     Var222      Var223 Var224 Var225 Var226 Var227               Var228 Var229
# 0  P6pu4Vl  LM8l689qOp    NaN   ELof   7P5s   ZI9m     R4y5gQQWY8OodqDV    NaN
# 1  S46Rt72  LM8l689qOp    NaN    NaN   Qu4f   RAYp        F2FyR07IdsN7I    NaN
# 2  CcdTy9x  LM8l689qOp    NaN    NaN   7aLG   RAYp        F2FyR07IdsN7I    NaN
# 3  Q53Rkup  LM8l689qOp    NaN   kG3k   7P5s   RAYp  TCU50_Yjmm6GIBZ0lL_   am7c
# 4  WfsWw2A  LM8l689qOp    NaN   ELof   5Acm   ZI9m           iyHGyLCEkQ   am7c

# %%
# Exclui as object e cria um novo dataset com as numéricas
data_num_test = data_test.drop(obj_test, axis=1)

# %%
# Visualização das primeiras linhas da coluna numérica de test
data_num_test.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10  Var11  \
# 0   NaN   NaN   NaN   NaN   NaN  1225.0   7.0   NaN   NaN    NaN    NaN
# 1   NaN   NaN   NaN   NaN   NaN   259.0   0.0   NaN   NaN    NaN    NaN
# 2   NaN   NaN   NaN   NaN   NaN   861.0  14.0   NaN   NaN    NaN    NaN
# 3   NaN   NaN   NaN   NaN   NaN  1568.0   7.0   NaN   NaN    NaN    NaN
# 4   NaN   NaN   NaN   NaN   NaN  1197.0   7.0   NaN   NaN    NaN    NaN
#
#    Var12   Var13  Var14  Var15  Var16  Var17  Var18  Var19  Var20  Var21  \
# 0    NaN   100.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  156.0
# 1    NaN     0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  192.0
# 2    NaN   236.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN   32.0
# 3    NaN  1232.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  448.0
# 4    NaN   204.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  100.0
#
#    Var22  Var23  Var24  Var25  Var26  Var27   Var28  Var29  Var30  Var31  \
# 0  195.0    NaN    0.0   72.0    NaN    NaN  166.56    NaN    NaN    NaN
# 1  240.0    NaN    0.0   40.0    NaN    NaN  300.32    NaN    NaN    NaN
# 2   40.0    NaN    0.0    8.0    NaN    NaN  186.64    NaN    NaN    NaN
# 3  560.0    NaN    4.0   88.0    NaN    NaN  166.56    NaN    NaN    NaN
# 4  125.0    NaN    8.0   40.0    NaN    NaN  133.12    NaN    NaN    NaN
#
#    Var32  Var33  Var34  Var35  Var36  Var37       Var38  Var39  Var40  Var41  \
# 0    NaN    NaN    NaN    0.0    NaN    NaN   4259232.0    NaN    NaN    NaN
# 1    NaN    NaN    NaN    5.0    NaN    NaN   4859550.0    NaN    NaN    NaN
# 2    NaN    NaN    NaN    0.0    NaN    NaN  10038840.0    NaN    NaN    NaN
# 3    NaN    NaN    NaN    0.0    NaN    NaN    116760.0    NaN    NaN    NaN
# 4    NaN    NaN    NaN    0.0    NaN    NaN    257772.0    NaN    NaN    NaN
#
#    Var42  Var43  Var44  Var45  Var46  Var47  Var48  Var49  Var50  Var51  \
# 0    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    Var52  Var53  Var54  Var55  Var56     Var57  Var58  Var59  Var60  Var61  \
# 0    NaN    NaN    NaN    NaN    NaN  2.565264    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN  1.464003    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN  4.737663    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN  4.292673    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN  1.977569    NaN    NaN    NaN    NaN
#
#    Var62  Var63  Var64  Var65  Var66  Var67  Var68  Var69  Var70  Var71  \
# 0    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN   18.0    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    9.0    NaN    NaN    NaN    NaN    NaN    NaN
#
#    Var72  Var73  Var74  Var75      Var76  Var77  Var78  Var79  Var80  \
# 0    NaN    106    7.0    NaN   959480.0    NaN    0.0    NaN    NaN
# 1    3.0     16    0.0    NaN  2413880.0    NaN    3.0    NaN    NaN
# 2    6.0     36   84.0    NaN  4104304.0    NaN    0.0    NaN    NaN
# 3    NaN    154    0.0    NaN   398120.0    NaN    0.0    NaN    NaN
# 4    NaN    138    7.0    NaN   728568.0    NaN    0.0    NaN    NaN
#
#        Var81  Var82  Var83  Var84  Var85  Var86  Var87  Var88  Var89  Var90  \
# 0   70399.20    NaN   15.0    NaN   10.0    NaN    NaN    NaN    NaN    NaN
# 1  145373.70    NaN   20.0    NaN   10.0    NaN    NaN    NaN    NaN    NaN
# 2  196722.00    NaN    5.0    NaN    0.0    NaN    NaN    NaN    NaN    NaN
#
NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Var180  Var181  Var182  Var183  Var184  Var185  Var186  Var187  Var188  \
# 0     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Var189  Var190  Var209  Var230
# 0     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN
# 2   198.0     NaN     NaN     NaN
# 3   336.0     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN

# %%
# Visualizando a quantidade de linhas e colunas
print("Shape do conjunto de dados de treino numérico (test)", data_num_test.shape)
print("Shape do conjunto de dados de treino object (test)", data_obj_test.shape)
# Out:
# Shape do conjunto de dados de treino numérico (test) (50000, 192)
# Shape do conjunto de dados de treino object (test) (50000, 38)

# %% [markdown]
# ### <b> Tratamento de missing value das variáveis numéricas

# %% [markdown]
# ##### <b> Deletando as colunas com 70 % de valores faltantes

# %%
# Deletando colunas com valor missing com mais de 70 % de ocorrência - train
numeric_missing_train =  data_num_train.drop(data_num_train.loc[:,list((100*(data_num_train.isnull().sum()/
                                             len(data_num_train.index))>70))].columns, 1)

# %%
# Deletando colunas com valor missing com mais de 70 % de ocorrência - test
numeric_missing_test = data_num_test.drop(data_num_test.loc[:,list((100*(data_num_test.isnull().sum()/
                                                      len(data_num_test.index))>70))].columns, 1)

# %%
# Visualizando o formato do dataset de treino após a exlusão dos missing
print("Shape do conjunto de dados após remoção de missing (test)", numeric_missing_test.shape)
print("Shape do conjunto de dados após remoção de missing (train)", numeric_missing_train.shape)
# Out:
# Shape do conjunto de dados após remoção de missing (test) (50000, 42)
# Shape do conjunto de dados após remoção de missing (train) (50000, 42)

# %%
# Verificando a quantidade de valores missing remanescentes do dataset de treino (Total)
numeric_missing_train.isnull().sum().sum()
# Out:
# 275418

# %%
# Verificando a quantidade de valores missing remanescentes do dataset de teste (Total)
numeric_missing_test.isnull().sum().sum()
# Out:
# 278139

# %% [markdown]
# ##### <b> Aplicando uma média nos valores missing que sobraram

# %%
# Aplicando a média aos valores que continuam missing e usando os nomes das colunas originais 
numeric_data_train = numeric_missing_train.fillna(numeric_missing_train.mean())
numeric_data_test = numeric_missing_test.fillna(numeric_missing_test.mean())

# %%
# Visualizando os resultados após aplicação da média
numeric_data_train.head()
# Out:
#           Var6  Var7   Var13        Var21   Var22      Var24  Var25   Var28  \
# 0  1526.000000   7.0   184.0   464.000000   580.0  14.000000  128.0  166.56
# 1   525.000000   0.0     0.0   168.000000   210.0   2.000000   24.0  353.52
# 2  5236.000000   7.0   904.0  1212.000000  1515.0  26.000000  816.0  220.08
# 3  1326.437116   0.0     0.0   234.518225     0.0   4.507926    0.0   22.08
# 4  1029.000000   7.0  3216.0    64.000000    80.0   4.000000   64.0  200.00
#
#    Var35      Var38  Var44     Var57  Var65     Var72  Var73  Var74  \
# 0    0.0     3570.0    0.0  4.076907    9.0  4.190659     36   35.0
# 1    0.0  4764966.0    0.0  5.408032    9.0  3.000000     26    0.0
# 2    0.0  5883894.0    0.0  6.599658    9.0  4.190659    130  518.0
# 3    0.0        0.0    0.0  1.988250    9.0  4.190659     12    0.0
# 4    0.0        0.0    0.0  4.552446   18.0  3.000000     82  224.0
#
#        Var76  Var78          Var81  Var83  Var85         Var94     Var109  \
# 0  1350864.0    0.0    7333.110000    5.0   12.0  98671.065858  104.00000
# 1   590.0    72.0      0.0  -0.514192    16.0  4322755.0   445056.0     0.0
# 2   265.0    24.0   1314.0  10.000000     0.0   170600.0   401068.0   260.0
# 3  1290.0    36.0  53865.0  -0.514192     0.0  1817570.0    90822.0   275.0
# 4   455.0    12.0   8334.0  64.000000     0.0    36465.0    49218.0   205.0
#
#    Var143  Var144    Var149      Var153  Var160     Var163  Var173  Var181  \
# 0     0.0     9.0       0.0   8335680.0    16.0  1689774.0     0.0     0.0
# 1     0.0     9.0       0.0  10646080.0    36.0  1038444.0     0.0     0.0
# 2     0.0    18.0       0.0  12102520.0     2.0        0.0     0.0     0.0
# 3     0.0    18.0  108871.0   1967840.0   140.0    82860.0     0.0     0.0
# 4     0.0    18.0   37737.0    752916.0     6.0   129618.0     0.0     0.0
#
#        Var189
# 0  268.981599
# 1  268.981599
# 2  198.000000
# 3  336.000000
# 4  268.981599

# %%
# Verificando a quantidade de valores missing remanescentes do dataset de treino (Total)
numeric_data_train.isnull().sum().sum()
# Out:
# 0

# %%
# Verificando a quantidade de valores missing remanescentes do dataset de teste (Total)
numeric_data_test.isnull().sum().sum()
# Out:
# 0

# %%
# Visualizando o formato do dataset de treino após a exlusão dos missing
print("Shape do conjunto de dados após finalizar o tratamento de missing numeric (test)", numeric_missing_test.shape)
print("Shape do conjunto de dados após finalizar o tratamento de missing numeric (train)", numeric_missing_train.shape)
# Out:
# Shape do conjunto de dados após finalizar o tratamento de missing numeric (test) (50000, 42)
# Shape do conjunto de dados após finalizar o tratamento de missing numeric (train) (50000, 42)

# %% [markdown]
# ### <b> Tratamento de missing value das variáveis object e conversão para valor numérico

# %%
# Deletando colunas com valor missing com mais de 70 % de ocorrência
object_train = data_obj_train.drop(data_obj_train.loc[:,list((100*(data_obj_train.isnull().sum()/
                                                      len(data_obj_train.index))>70))].columns, 1)

# Deletando colunas com valor missing com mais de 70 % de ocorrência
object_test = data_obj_test.drop(data_obj_test.loc[:,list((100*(data_obj_test.isnull().sum()/
                                                      len(data_obj_test.index))>70))].columns, 1)

# %%
# Visualizando o formato do dataset de treino após a exlusão dos missing
print("Shape do conjunto de dados após remover missing object (test)", object_test.shape)
print("Shape do conjunto de dados após remover missing object (train)", object_train.shape)
# Out:
# Shape do conjunto de dados após remover missing object (test) (50000, 32)
# Shape do conjunto de dados após remover missing object (train) (50000, 32)

# %%
# Visualizando a quantidade de nulos (total) após a remoção 
print("Test = ", object_test.isnull().sum().sum())
print("Train = ", object_train.isnull().sum().sum())
# Out:
# Test =  125228
# Train =  125486

# %%
# Substituindo todos os valores faltantes para a string 'Missing' (test)
object_test = object_test.replace(np.nan, 'Missing')
# Verificando a ocorrência de nulos após tratamento
object_test.isnull().sum().sum()
# Out:
# 0

# %%
# Substituindo todos os valores faltantes para a string 'Missing' (train)
object_train = object_train.replace(np.nan, 'Missing')
# Verificando a ocorrência de nulos após tratamento
object_train.isnull().sum().sum()
# Out:
# 0

# %%
# Visualizando o formato do dataset de treino após a exlusão dos missing
print("Shape do conjunto de dados após finalizar remoção missing object (test)", object_test.shape)
print("Shape do conjunto de dados após finalizar remoção missing object (train)", object_train.shape)
# Out:
# Shape do conjunto de dados após finalizar remoção missing object (test) (50000, 32)
# Shape do conjunto de dados após finalizar remoção missing object (train) (50000, 32)

# %% [markdown]
# ##### <b> Convertendo as colunas objects em numeric (Test)

# %%
# Aplicando o método rank que gera um valor numérico para cada ocorrência de strings iguais no dataset
object_to_numeric_test = object_test.rank(method='dense', ascending=False).astype(float)

# %%
# Visualizando o resultado
object_to_numeric_test.head()
# Out:
#    Var192  Var193  Var195  Var196  Var197  Var198  Var199   Var200  Var202  \
# 0    15.0    25.0     1.0     4.0   132.0  1163.0  5070.0   9680.0  2709.0
# 1   131.0    25.0     1.0     4.0    46.0   458.0  4596.0   9521.0  2297.0
# 2     3.0    25.0     1.0     4.0    38.0  3024.0  2026.0   9521.0  5029.0
# 3    98.0    47.0     1.0     4.0    21.0  2170.0  1624.0    747.0  1398.0
# 4    22.0     9.0     1.0     4.0   205.0  1297.0  1170.0  10563.0  1011.0
#
#    Var203  Var204  Var205  Var206  Var207  Var208  Var210  Var211  Var212  \
# 0     5.0     8.0     2.0    10.0    10.0     2.0     1.0     2.0    57.0
# 1     5.0    10.0     2.0     1.0     4.0     2.0     1.0     2.0    48.0
# 2     5.0    26.0     2.0     1.0     4.0     2.0     1.0     2.0    48.0
# 3     5.0     8.0     2.0    19.0     4.0     2.0     1.0     2.0    37.0
# 4     5.0    49.0     2.0     7.0    10.0     2.0     1.0     2.0    57.0
#
#     Var214  Var216   Var217  Var218  Var219  Var220  Var221  Var222  Var223  \
# 0   7354.0  1841.0   8551.0     1.0    11.0  1427.0     7.0  2567.0     5.0
# 1   9936.0   688.0  12986.0     1.0    11.0  2914.0     3.0  2350.0     5.0
# 2   9936.0   700.0  13942.0     1.0    11.0  1544.0     3.0  3443.0     5.0
# 3  14552.0  1201.0   6538.0     2.0    14.0   598.0     3.0  2475.0     5.0
# 4   6042.0  1155.0   5538.0     1.0    11.0  1233.0     7.0  2049.0     5.0
#
#    Var225  Var226  Var227  Var228  Var229
# 0     4.0    21.0     4.0    19.0     5.0
# 1     3.0    14.0     5.0    22.0     5.0
# 2     3.0    20.0     5.0    22.0     5.0
# 3     2.0    21.0     5.0    16.0     4.0
# 4     4.0    23.0     4.0     4.0     4.0

# %%
# Visualizando o novo formato de dados
object_to_numeric_test.dtypes[0]
# Out:
# dtype('float64')

# %% [markdown]
# ##### <b> Convertendo as colunas objects em numeric (Train)

# %%
# Aplicando o método rank que gera um valor numérico para cada ocorrência de strings iguais no dataset
object_to_numeric_train = object_train.rank(method='dense', ascending=False).astype(float)

# %%
# Visualizando o resultado
object_to_numeric_train.head()
# Out:
#    Var192  Var193  Var195  Var196  Var197  Var198  Var199   Var200  Var202  \
# 0   136.0    26.0     1.0     4.0    48.0   989.0  1058.0   9485.0  2031.0
# 1   271.0    26.0     1.0     4.0   213.0   594.0   183.0   9485.0  1291.0
# 2  3443.0     5.0     3.0    20.0     5.0    22.0     5.0
# 3  2475.0     5.0     2.0    21.0     5.0    16.0     4.0
# 4  2049.0     5.0     4.0    23.0     4.0     4.0     4.0

# %%
print(data_test_final.shape, data_train_final.shape, numeric_data_test.shape, numeric_data_train.shape)
# Out:
# (50000, 74) (50000, 74) (50000, 42) (50000, 42)

# %% [markdown]
# <b> Analizando os dados

# %%
def Outliers(data):
    data_mean, data_std = data.mean(), data.std() 
    cut_off = data_std * 3
    lower, upper = data_std - cut_off, data_std + cut_off
    # identify outliers
    outliers = [x for x in  data if x < lower or x > upper]
    print('Outliers: %d' % len(outliers))
    # remove outliers
    outliers_removed = [x for x in data if x > lower and x < upper]
    print('Não Outliers: %d' % len(outliers_removed))
    return outliers

# %%
o = data_train_final.apply(Outliers)
# Out:
# Outliers: 340
# Não Outliers: 49660
# Outliers: 967
# Não Outliers: 49033
# Outliers: 466
# Não Outliers: 49534
# Outliers: 297
# Não Outliers: 49703
# Outliers: 298
# Não Outliers: 49702
# Outliers: 410
# Não Outliers: 49590
# Outliers: 330
# Não Outliers: 49670
# Outliers: 1936
# Não Outliers: 48064
# Outliers: 643
# Não Outliers: 49357
# Outliers: 175
# Não Outliers: 49825
# Outliers: 670
# Não Outliers: 49330
# Outliers: 0
# Não Outliers: 50000
# Outliers: 1625
# Não Outliers: 48375
# Outliers: 2441
# Não Outliers: 47559
# Outliers: 455
# Não Outliers: 49545
# Outliers: 44
# Não Outliers: 49956
# Outliers: 443
# Não Outliers: 49557
# Outliers: 1111
# Não Outliers: 48889
# Outliers: 439
# Não Outliers: 49561
# Outliers: 208
# Não Outliers: 49792
# Outliers: 365
# Não Outliers: 49635
# Outliers: 681
# Não Outliers: 49319
# Outliers: 317
# Não Outliers: 49683
# Outliers: 300
# Não Outliers: 49700
# Outliers: 2994
# Não Outliers: 47006
# Outliers: 295
# Não Outliers: 49705
# Outliers: 201
# Não Outliers: 49799
# Outliers: 236
# Não Outliers: 49764
# Outliers: 0
# Não Outliers: 50000
# Outliers: 1091
# Não Outliers: 48909
# Outliers: 868
# Não Outliers: 49132
# Outliers: 990
# Não Outliers: 49010
# Outliers: 391
# Não Outliers: 49609
# Outliers: 396
# Não Outliers: 49604
# Outliers: 1177
# Não Outliers: 48823
# Outliers: 343
# Não Outliers: 49657
# Outliers: 0
# Não Outliers: 50000
# Outliers: 315
# Não Outliers: 49685
# Outliers: 690
# Não Outliers: 49310
# Outliers: 134
# Não Outliers: 49866
# Outliers: 822
# Não Outliers: 49178
# Outliers: 43121
# Não Outliers: 6879
# Outliers: 0
# Não Outliers: 50000
# Outliers: 9696
# Não Outliers: 40304
# Outliers: 1731
# Não Outliers: 48269
# Outliers: 49568
# Não Outliers: 432
# Outliers: 0
# Não Outliers: 50000
# Outliers: 0
# Não Outliers: 50000
# Outliers: 0
# Não Outliers: 50000
# Outliers: 3879
# Não Outliers: 46121
# Outliers: 0
# Não Outliers: 50000
# Outliers: 49995
# Não Outliers: 5
# Outliers: 0
# Não Outliers: 50000
# Outliers: 11574
# Não Outliers: 38426
# Outliers: 0
# Não Outliers: 50000
# Outliers: 7118
# Não Outliers: 42882
# Outliers: 46165
# Não Outliers: 3835
# Outliers: 2256
# Não Outliers: 47744
# Outliers: 40299
# Não Outliers: 9701
# Outliers: 39743
# Não Outliers: 10257
# Outliers: 3752
# Não Outliers: 46248
# Outliers: 0
# Não Outliers: 50000
# Outliers: 0
# Não Outliers: 50000
# Outliers: 703
# Não Outliers: 49297
# Outliers: 42316
# Não Outliers: 7684
# Outliers: 0
# Não Outliers: 50000
# Outliers: 3467
# Não Outliers: 46533
# Outliers: 0
# Não Outliers: 50000
# Outliers: 0
# Não Outliers: 50000
# Outliers: 11072
# Não Outliers: 38928
# Outliers: 0
# Não Outliers: 50000
# Outliers: 47077
# Não Outliers: 2923
# Outliers: 4594
# Não Outliers: 45406
# Outliers: 40121
# Não Outliers: 9879

# %%
outliers_list = data_train_final[data_train_final['Var6'] == o[0]].index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-9ceaa5e62111> in <module>
# ----> 1 outliers_list = data_train_final[data_train_final['Var6'] == o[0]].index
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1743             # as it will broadcast
#    1744             if other.ndim != 0 and len(self) != len(other):
# -> 1745                 raise ValueError('Lengths must match to compare')
#    1746
#    1747             res_values = na_op(self.values, np.asarray(other))
#
# ValueError: Lengths must match to compare

# %%
data_train_final.drop(outliers_list, axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-71c1820e29ed> in <module>
# ----> 1 data_train_final.drop(outliers_list, axis=0, inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4958         arr_dtype = 'object' if self.dtype == 'object' else None
#    4959         labels = com.index_labels_to_array(labels, dtype=arr_dtype)
# -> 4960         indexer = self.get_indexer(labels)
#    4961         mask = indexer == -1
#    4962         if mask.any():
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    2735             target = target.astype(object)
#    2736             return this.get_indexer(target, method=method, limit=limit,
# -> 2737                                     tolerance=tolerance)
#    2738
#    2739         if not self.is_unique:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    2753                                  'backfill or nearest reindexing')
#    2754
# -> 2755             indexer = self._engine.get_indexer(target._ndarray_values)
#    2756
#    2757         return ensure_platform_int(indexer)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ##### <b> Normalizando os dados

# %%
# Como os dados estão muito distintos uns dos outros aplico a fórmula de normalização
# para padronizar
data_test_final_normalized = (data_test_final - data_test_final.mean() )/ (data_test_final.std())
data_train_final_normalized = (data_train_final - data_train_final.mean() )/ (data_train_final.std())

# %%
# Visualizando o resultado dos dados normalizados de teste
data_test_final_normalized.head(2)
# Out:
#        Var6      Var7     Var13     Var21    Var22     Var24     Var25  \
# 0 -0.029007  0.019206 -0.436512 -0.095072 -0.09239 -0.320665 -0.088229
# 1 -0.243353 -1.153169 -0.474336 -0.055028 -0.05274 -0.320665 -0.187516
#
#       Var28     Var35     Var38     Var44     Var57     Var65         Var72  \
# 0 -0.639388 -0.253029  0.601916 -0.117297 -0.461381 -0.625602  5.574478e-13
# 1  0.848322  1.505833  0.814139 -0.117297 -1.008235 -0.625602 -7.048215e-01
#
#       Var73     Var74     Var76     Var78     Var81     Var83     Var85  \
# 0  0.747062 -0.209143 -0.315564 -0.260626 -0.328657 -0.044410  0.035814
# 1 -0.959868 -0.224295  0.513452  1.262743  0.423979 -0.008637  0.035814
#
#           Var94    Var109    Var112    Var113    Var119    Var123    Var125  \
# 0  8.348294e-14 -0.140462 -0.120581  0.700445 -0.068409 -0.024586 -0.087412
# 1  2.695225e+00 -0.140462 -0.153938  0.385802 -0.074518  0.022798 -0.335770
#
#          Var126    Var132    Var133    Var134    Var140    Var143    Var144  \
# 0  9.247237e-15 -0.369696 -0.667143  1.207864  0.184201 -0.099859 -0.256414
# 1  9.247237e-15  1.358787  0.867604  0.011312 -0.472221 -0.099859 -0.256414
#
#      Var149    Var153    Var160    Var163    Var173    Var181        Var189  \
# 0 -0.492576  0.519907 -0.176579  1.493131 -0.056082 -0.250983  1.650297e-12
# 1 -0.492576  1.082627 -0.023779  0.680951 -0.056082 -0.250983  1.650297e-12
#
#      Var192    Var193   Var195    Var196    Var197    Var198    Var199  \
# 0 -1.579776 -0.385356 -0.18497  0.097051  0.069803 -0.758019  1.704952
# 1 -0.518234 -0.385356 -0.18497  0.097051 -1.077996 -1.354892  1.368747
#
#      Var200    Var202    Var203    Var204    Var205    Var206    Var207  \
# 0  0.317309 -0.053218  0.311102 -1.362892 -0.434594 -0.173809  1.976939
# 1  0.268749 -0.305986  0.311102 -1.295378 -0.434594 -1.612310 -0.591704
#
#      Var208    Var210   Var211    Var212    Var214    Var216    Var217  \
# 0  0.275509 -0.200366  0.48567  0.901082 -0.471877  1.495463  0.348801
# 1  0.275509 -0.200366  0.48567  0.030733  0.304581 -0.569297  1.447121
#
#      Var218    Var219    Var220    Var221    Var222    Var223    Var225  \
# 0 -0.953527  0.314073 -0.693000  3.531242  0.329071  0.544108  1.382476
# 1 -0.953527  0.314073  0.508523 -0.016836  0.145230  0.544108  0.109525
#
#      Var226    Var227   Var228    Var229
# 0  1.052199 -1.017356 -0.11544  0.790068
# 1 -0.042516  0.119787  0.34727  0.790068

# %%
# Visualizando o resultado dos dados normalizados de treino
data_train_final_normalized.head(2)
# Out:
#        Var6      Var7     Var13     Var21     Var22     Var24     Var25  \
# 0  0.078790  0.031935 -0.404344  0.430246  0.433589  1.033665  0.153335
# 1 -0.316417 -1.141506 -0.474158 -0.124712 -0.120079 -0.273107 -0.358225
#
#       Var28     Var35     Var38     Var44     Var57     Var65         Var72  \
# 0 -0.620073 -0.252223 -0.902013 -0.107943  0.278691 -0.614119 -2.872485e-13
# 1  1.380505 -0.252223  0.765539 -0.107943  0.935751 -0.614119 -6.950807e-01
#
#       Var73     Var74     Var76     Var78     Var81     Var83     Var85  \
# 0 -0.579674 -0.094963 -0.079214 -0.263978 -0.955368 -0.179711  0.180926
# 1 -0.768856 -0.143373  0.786386  1.217083  0.479075  0.059528 -0.330313
#
#           Var94    Var109    Var112    Var113    Var119    Var123    Var125  \
# 0  2.921177e-13  0.330006  0.680645  0.355810  0.126769 -0.257841 -0.319658
# 1 -3.017686e-01 -0.159897 -0.175353 -0.266798 -0.159687  0.056204 -0.328130
#
#          Var126    Var132    Var133    Var134    Var140    Var143    Var144  \
# 0  4.469048e-01 -0.371755 -0.458748 -0.642291 -0.317902 -0.095101 -0.246774
# 1 -5.771453e-15  0.472036  0.805308 -0.140078 -0.367065 -0.095101 -0.246774
#
#      Var149    Var153   Var160    Var163    Var173    Var181        Var189  \
# 0  0.168972 -1.059239  1.09340 -0.555946 -0.054466 -0.258285  3.412526e+00
# 1 -0.027301  1.031963 -0.07208 -0.307376 -0.054466 -0.258285  1.315388e-12
#
#      Var192    Var193    Var195    Var196    Var197    Var198    Var199  \
# 0 -0.483503 -0.388068 -0.189859  0.094479 -1.038077 -0.900953 -1.098653
# 1  0.784670 -0.388068 -0.189859  0.094479  1.258141 -1.230864 -1.731896
#
#      Var200    Var202    Var203    Var204    Var205    Var206    Var207  \
# 0  0.267958 -0.488311  0.309759  0.854950 -0.436619 -0.172344 -0.590521
# 1  0.267958 -0.941186  0.309759 -0.907567 -1.498849 -1.624438 -0.590521
#
#      Var208    Var210    Var211    Var212   Var214    Var216    Var217  \
# 0  0.271241 -0.209332  0.490633 -1.054730  0.30548  0.385883 -1.345261
# 1  0.271241 -0.209332  0.490633  0.032178  0.30548 -0.565633  0.462701
#
#      Var218    Var219    Var220    Var221    Var222    Var223    Var225  \
# 0 -0.962755  0.311287  1.529688 -0.014225 -0.709986 -2.391476  0.103991
# 1  2.830007  0.311287  1.596993 -0.014225  1.688747  0.541339  0.103991
#
#      Var226    Var227    Var228    Var229
# 0 -2.049566  0.118734  0.344222  0.789914
# 1 -0.669884  0.118734  0.344222  0.789914

# %% [markdown]
# ### <b>Tratamento das variáveis Target (appetency, up_selling and churn)

# %%
# Substituindo o -1 pelo 0
appetency_label = appetency_label.replace(-1, 0)
churn_label = churn_label.replace(-1, 0)
up_label = up_label.replace(-1, 0)

# %%
# Adicionando uma nova linha para combinar com o tamanho total do dataset
appetency_label.loc[50000] = [0] 
churn_label.loc[50000] = [0] 
up_label.loc[50000] = [0]

# %% [markdown]
# ## <b> Visualização do Shape após limpeza e organização

# %%
# Padronizando o nome dos dados de treino
X_train = data_train_final_normalized
X_test = data_test_final_normalized

# %%
# Padronizando os nomes das variáveis Target
y_appetency = appetency_label
y_churn = churn_label
y_up = up_label

# %%
print(X_train.shape, X_test.shape)
# Out:
# (50000, 74) (50000, 74)

# %%
print(y_appetency.shape, y_churn.shape, y_up.shape)
# Out:
# (50000, 1) (50000, 1) (50000, 1)

# %% [markdown]
# # <b> Treinando os dados

# %%
# Instâncias dos Classificadores
dtree = tree.DecisionTreeClassifier(random_state=0, max_depth=2)
logreg  = LogisticRegression(random_state=0, solver='lbfgs', penalty='l2')

# %% [markdown]
# ### <b> Regressão Logística

# %% [markdown]
# ##### <b> Appetency

# %%
# Ajustando os dados - Logistic Regression
logreg.fit(X_train, y_appetency)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
# Predizendo os valores 
predLRAPP = logreg.predict(X_test)

# %%
# Verificando a acurária do modelo
acc_lr_appetency = metrics.accuracy_score(y_appetency, predLRAPP)
print("Accuracy", acc_lr_appetency)
# Out:
# Accuracy 0.9822

# %%
# Visualizando os resultados
print(classification_report(y_appetency,predLRAPP))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     49110
#            1       0.00      0.00      0.00       890
#
#    micro avg       0.98      0.98      0.98     50000
#    macro avg       0.49      0.50      0.50     50000
# weighted avg       0.96      0.98      0.97     50000

# %%
# Matriz de confusão
cm = confusion_matrix(y_appetency, predLRAPP)
print(cm)
sea.heatmap(cm)
plt.title('Appetency - Logistic Regression')
plt.savefig("LR_app.png")
# Out:
# [[49110     0]
#  [  890     0]]

# %%
# Calculando os valores para o roc_auc e plotando o gráfico
auc_lr_app = roc_auc_score(y_appetency, logreg.predict_proba(X_test)[:,1])
fpr, tpr, thresholds = roc_curve(y_appetency, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Classifier (area = %0.2f)' % auc_lr_app)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Appetency - Logistic Regression')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig("auc_lr_app")

# %% [markdown]
# ##### <b> Churn

# %%
# Ajustando os dados - Logistic Regression
logreg.fit(X_train, y_churn)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
# Predizendo os valores 
pred = logreg.predict(X_test)

# %%
# Verificando a acurária do modelo
acc_lr_churn = metrics.accuracy_score(y_churn, pred)
print("Accuracy", acc_lr_churn)
# Out:
# Accuracy 0.92656

# %%
# Visualizando os resultados
print(classification_report(y_churn,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     46328
#            1       0.00      0.00      0.00      3672
#
#    micro avg       0.93      0.93      0.93     50000
#    macro avg       0.46      0.50      0.48     50000
# weighted avg       0.86      0.93      0.89     50000

# %%
# Matriz de confusão
cm = confusion_matrix(y_churn, pred)
print(cm)
sea.heatmap(cm)
plt.title('Churn - Logistic Regression')
plt.savefig("LR_churn.png")
# Out:
# [[46328     0]
#  [ 3672     0]]

# %%
# Calculando os valores para o roc_auc e plotando o gráfico
auc_lr_churn = roc_auc_score(y_churn, logreg.predict_proba(X_test)[:,1])
fpr, tpr, thresholds = roc_curve(y_churn, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Classifier (area = %0.2f)' % auc_lr_churn)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Churn - Logistic Regression')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig("auc_lr_churn.png")

# %% [markdown]
# ##### <b> up_selling

# %%
# Ajustando os dados - Logistic Regression
logreg.fit(X_train, y_up)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
# Predizendo os valores 
pred = logreg.predict(X_test)

# %%
# Verificando a acurária do modelo
acc_lr_up = metrics.accuracy_score(y_up, pred)
print("Accuracy", acc_lr_up)
# Out:
# Accuracy 0.92628

# %%
# Visualizando os resultados
print(classification_report(y_up,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     46318
#            1       0.00      0.00      0.00      3682
#
#    micro avg       0.93      0.93      0.93     50000
#    macro avg       0.46      0.50      0.48     50000
# weighted avg       0.86      0.93      0.89     50000

# %%
# Matriz de confusão
cm = confusion_matrix(y_up, pred)
print(cm)

plt.title('Up_selling - Logistic Regression')
sea.heatmap(cm)
plt.savefig("LR_up.png")
# Out:
# [[46314     4]
#  [ 3682     0]]

# %%
# Calculando os valores para o roc_auc e plotando o gráfico
auc_lr_up = roc_auc_score(y_up, logreg.predict_proba(X_test)[:,1])
fpr, tpr, thresholds = roc_curve(y_up, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Classifier (area = %0.2f)' % auc_lr_up)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Up_selling - Logistic Regression')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig("auc_lr_up.png")
plt.show()

# %% [markdown]
# ### <b> Decision Tree

# %% [markdown]
# ##### <b> Appetency

# %%
# Ajustando os dados - Decision Tree
dtree.fit(X_train, y_appetency)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
# Predizendo os valores 
pred = dtree.predict(X_test)

# %%
# Verificando a acurária do modelo
acc_dt_appetency = metrics.accuracy_score(y_appetency, pred)
print("Accuracy", acc_dt_appetency)
# Out:
# Accuracy 0.9822

# %%
# Visualizando os resultados
print(classification_report(y_appetency,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     49110
#            1       0.00      0.00      0.00       890
#
#    micro avg       0.98      0.98      0.98     50000
#    macro avg       0.49      0.50      0.50     50000
# weighted avg       0.96      0.98      0.97     50000

# %%
# Matriz de confusão
cm = confusion_matrix(y_appetency, pred)
print(cm)
sea.heatmap(cm)
plt.title('Appetency - Decision Tree')
plt.savefig("DT_app.png")
# Out:
# [[49110     0]
#  [  890     0]]

# %%
# Calculando os valores para o roc_auc e plotando o gráfico
auc_dt_app = roc_auc_score(y_appetency, dtree.predict_proba(X_test)[:,1])
fpr, tpr, thresholds = roc_curve(y_appetency, dtree.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Classifier (area = %0.2f)' % auc_dt_app)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Appetency - Decision Tree')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig("auc_dt_app.png")
plt.show()

# %% [markdown]
# ##### <b> Churn

# %%
# Ajustando os dados - Decision Tree
dtree.fit(X_train, y_churn)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
# Predizendo os valores 
pred = dtree.predict(X_test)

# %%
# Verificando a acurária do modelo
acc_dt_churn= metrics.accuracy_score(y_churn, pred)
print("Accuracy", acc_dt_churn)
# Out:
# Accuracy 0.92644

# %%
# Visualizando os resultados
print(classification_report(y_churn,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     46328
#            1       0.00      0.00      0.00      3672
#
#    micro avg       0.93      0.93      0.93     50000
#    macro avg       0.46      0.50      0.48     50000
# weighted avg       0.86      0.93      0.89     50000

# %%
# Matriz de confusão
cm = confusion_matrix(y_churn, pred)
print(cm)
sea.heatmap(cm)
plt.title('Churn - Decision Tree')
plt.savefig("DT_churn.png")
# Out:
# [[46322     6]
#  [ 3672     0]]

# %%
# Calculando os valores para o roc_auc e plotando o gráfico
auc_dt_churn = roc_auc_score(y_churn, dtree.predict_proba(X_test)[:,1])
fpr, tpr, thresholds = roc_curve(y_churn, dtree.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Classifier (area = %0.2f)' % auc_dt_churn)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Churn - Decision Tree')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig("auc_dt_churn.png")
plt.show()

# %% [markdown]
# ##### <b> Up_selling

# %%
# Ajustando os dados - Decision Tree
dtree.fit(X_train, y_up)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
# Predizendo os valores 
pred= dtree.predict(X_test)

# %%
# Verificando a acurária do modelo
acc_dt_up = metrics.accuracy_score(y_up, pred)
print("Accuracy", acc_dt_up)
# Out:
# Accuracy 0.88876

# %%
# Visualizando os resultados
print(classification_report(y_up,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94     46318
#            1       0.08      0.05      0.06      3682
#
#    micro avg       0.89      0.89      0.89     50000
#    macro avg       0.50      0.50      0.50     50000
# weighted avg       0.86      0.89      0.88     50000

# %%
# Matriz de confusão
cm = confusion_matrix(y_up, pred)
print(cm)
sea.heatmap(cm)
plt.title('Up_Selling - Decision Tree')
plt.savefig("DT_up.png")
# Out:
# [[44266  2052]
#  [ 3510   172]]

# %%
# Calculando os valores para o roc_auc e plotando o gráfico
auc_dt_up = roc_auc_score(y_up, dtree.predict_proba(X_test)[:,1])
fpr, tpr, thresholds = roc_curve(y_up, dtree.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Classifier (area = %0.2f)' % auc_dt_up)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Up_Selling - Decision Tree')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig("auc_dt_up.png")
plt.show()

# %% [markdown]
# ### <b> Organizando os resultados para melhor visualização

# %%
# Criando um dicionário para organizar os dados
dict_info = {'Appetency':[acc_dt_appetency, acc_lr_appetency], 
            'Churn': [acc_dt_churn, acc_lr_churn],
             'Up_selling': [acc_dt_up, acc_lr_up]}
dict_info
# Out:
# {'Appetency': [0.9822, 0.9822],
#  'Churn': [0.92644, 0.92656],
#  'Up_selling': [0.88876, 0.92628]}

# %%
# Criando um dataframe com os dados organizados em colunas
results = pd.DataFrame(dict_info, index = ['Decision Tree', 'Logistic Regression'])

# %%
results
# Out:
#                      Appetency    Churn  Up_selling
# Decision Tree           0.9822  0.92644     0.88876
# Logistic Regression     0.9822  0.92656     0.92628

# %%
# Criando um dicionário para organizar os dados
dict_auc = {'Appetency':[auc_dt_app, auc_lr_app], 
            'Churn': [auc_dt_churn, auc_lr_churn],
             'Up_selling': [auc_dt_up, auc_lr_up]}
dict_auc
# Out:
# {'Appetency': [0.4999898187741804, 0.5068671796174148],
#  'Churn': [0.49747919095591575, 0.49889639104552963],
#  'Up_selling': [0.5012061600274643, 0.5011477641552146]}

# %%
# Criando um dataframe com os dados organizados em colunas
auc_results = pd.DataFrame(dict_auc, index = ['Decision Tree', 'Logistic Regression'])

# %%
auc_results
# Out:
#                      Appetency     Churn  Up_selling
# Decision Tree         0.499990  0.497479    0.501206
# Logistic Regression   0.506867  0.498896    0.501148
